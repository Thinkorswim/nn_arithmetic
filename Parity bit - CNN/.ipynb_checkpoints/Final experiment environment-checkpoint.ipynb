# %%
import keras
from keras.models import Sequential, Model
from keras.layers.core import Dense, Dropout, Activation
from keras.layers import Input, Conv1D, MaxPooling1D, GlobalMaxPooling1D, GlobalAveragePooling1D, Flatten
from keras import regularizers
from sklearn.metrics import confusion_matrix

import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from keras.layers.normalization import BatchNormalization


from IPython import embed


def import_data(dataset="data"):
    X = []
    Y = []

    f=open(dataset, 'r')
    for line in f.readlines():
        intLine = [int(s) for s in line.split(' ')]
        X.append(intLine[:-1])
        Y.append(intLine[-1:])
    
    X = np.array(X)
    X = X.reshape(X.shape[0],X.shape[1],1)
    Y = np.array(Y)
    return X,Y

def create_CCN_model(input_size, f, k):
    model = Sequential()

    model.add(Conv1D(f, k, activation='selu', kernel_initializer="lecun_uniform", input_shape=(input_size, 1 ))) 
    model.add(Flatten()) 
    
    model.add(Dense(input_size, activation='selu', kernel_initializer="lecun_uniform"))
    model.add(Dense(1,activation="sigmoid"))
    model.compile(loss='binary_crossentropy', optimizer=keras.optimizers.Adadelta(lr=1.0, rho=0.95, epsilon=None, decay=0.0), metrics=['binary_crossentropy', 'accuracy'])
    return model

def draw_figure(data, label, fig=None, ax=None):
    # Plot the change in the validation set vs change in the training set
    if not fig:
        fig = plt.figure(figsize=(6, 4))
    if not ax:
        ax = fig.add_subplot(111)
    
    
    real_data = []
    scale = int(len(data[0])/50)
    
    
    
    for i in range(0, 50):
        real_data.append(data[0][i*scale])
    
    ax.plot(np.arange(1, len(data[0]) + 1, scale), real_data, label=label)
    ax.legend(loc='best')
    ax.set_xlabel('Epoch number')
    return fig, ax

# %%
test_size = 0.2
epochs = [1000, 2000, 3000]
b_size = 100
tries = 1
exp = 'final_30'


histories = np.array([])

X, Y = import_data()

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = test_size)

X_train = np.array(X_train)
X_test = np.array(X_test)
Y_train = np.array(Y_train)
Y_test = np.array(Y_test)

print("\nTraining examples: " +  str(X_train.shape[0]))
print("Test examples: " +  str(X_test.shape[0]))


input_size = len(X_train[0])


filters = [int(input_size/4), int(input_size*2)]
kernel_size = [ input_size ]

print(kernel_size)

for f in filters:
    for ks in kernel_size:
        for ep in epochs:
            avg_val = np.array([])
            avg_train = np.array([])
            for t in range(tries):
                print("Epochs: " + str(ep) + '  -------  Try: ' + str(t))
                classifier = create_CCN_model(len(X_train[0]), f, ks)
                classifier.summary()

                history = classifier.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=ep, batch_size=b_size, verbose=1)
                result = classifier.evaluate(X_test, Y_test, batch_size=b_size)

                avg_val = np.append(avg_val, result[2])
                avg_train = np.append(avg_train, history.history['acc'][-1])
                histories = np.append(histories, history)

                val_acc = history.history['val_acc']
                train_acc = history.history['acc']

                with open(exp + '/acc_' + str(len(X_train[0])) + '_' + str(ep) + '_' + str(t) +'_' + str(f) + '_' + str(ks) + '.txt', "w") as file:
                    file.write('val_acc  ' + str(val_acc))
                    file.write('\ntrain_acc  ' + str(train_acc))

                fig, ax = draw_figure([train_acc], 'Training Accuracy')
                fig, ax = draw_figure([val_acc], 'Validation Accuracy', fig, ax)

                ax.grid('on')
                fig.tight_layout() 
                fig.savefig(exp + '/graph_' + str(len(X_train[0])) + '_' + str(ep) + '_' + str(t) + '_' + str(f) + '_' + str(ks) + '.pdf')
                plt.show() 



                print(confusion_matrix(classifier.predict(X_test)>0.5, Y_test))

                print("\nValidation Avg: " + str(avg_val))
                print("Train Avg: " + str(avg_train))
                print("\n")

                c = 0
                classifications = (classifier.predict(X_test) > 0.5 ) == Y_test
                for i, flag in enumerate(classifications):
                    if(flag == False and c<=10):
                        print(str(X_test[i]) + "    " + str(Y_test[i]))
                        c += 1

                c = 0
                with open(exp + '/data_' + str(len(X_train[0])) + '_' + str(ep) + '_' + str(t) + '_' + str(f) + '_' + str(ks) +'.txt', "w") as file:
                    file.write(str(confusion_matrix(classifier.predict(X_test)>0.5, Y_test)))

                    file.write("\nValidation Avg: " + str(np.average(avg_val)))
                    file.write("\nTrain Avg: " + str(np.average(avg_train)))
                    file.write("\n\n")

                    for i, flag in enumerate(classifications):
                        if(flag == False and c<=10):
                            file.write('\n' + str(X_test[i]) + "    " + str(Y_test[i]))
                            c += 1


                print("\n\n")
            print("\n Overall for: " + str(len(X_train[0])) + '_' + str(ep))
            print(avg_val)
            print(avg_train)
            print("\nOVERALL VAL: " + str(np.average(avg_val)))
            print("OVERALL TRAIN: " + str(np.average(avg_train)))
            print("\n")

            with open(exp + '/data_' + str(len(X_train[0])) + '_' + str(ep) + '_' + str(f) + '_' + str(ks) + '.txt', "w") as file:
                file.write(str(avg_val))
                file.write("\n" + str(avg_train))
                file.write("\n\nOVERALL VAL: " + str(np.average(avg_val)))
                file.write("\nOVERALL TRAIN: " + str(np.average(avg_train)))
# Out:
# Training examples: 80000
# Test examples: 20000
# [30]
# Epochs: 5000  -------  Try: 0
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 1, 7)              217
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                240
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 488
# Trainable params: 488
# Non-trainable params: 0
# _________________________________________________________________
# Train on 80000 samples, validate on 20000 samples
# Epoch 1/5000
# 80000/80000 [==============================] - 2s 25us/step - loss: 0.6955 - binary_crossentropy: 0.6955 - acc: 0.5015 - val_loss: 0.6949 - val_binary_crossentropy: 0.6949 - val_acc: 0.4948
# Epoch 2/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6942 - binary_crossentropy: 0.6942 - acc: 0.5018 - val_loss: 0.6947 - val_binary_crossentropy: 0.6947 - val_acc: 0.4977
# Epoch 3/5000
# 80000/80000 [==============================] - 2s 21us/step - loss: 0.6939 - binary_crossentropy: 0.6939 - acc: 0.5026 - val_loss: 0.6941 - val_binary_crossentropy: 0.6941 - val_acc: 0.5025
# Epoch 4/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6936 - binary_crossentropy: 0.6936 - acc: 0.5045 - val_loss: 0.6945 - val_binary_crossentropy: 0.6945 - val_acc: 0.4985
# Epoch 5/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6934 - binary_crossentropy: 0.6934 - acc: 0.5074 - val_loss: 0.6970 - val_binary_crossentropy: 0.6970 - val_acc: 0.4952
# Epoch 6/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6933 - binary_crossentropy: 0.6933 - acc: 0.5088 - val_loss: 0.6939 - val_binary_crossentropy: 0.6939 - val_acc: 0.5001
# Epoch 7/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6931 - binary_crossentropy: 0.6931 - acc: 0.5105 - val_loss: 0.6969 - val_binary_crossentropy: 0.6969 - val_acc: 0.4953
# Epoch 8/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6931 - binary_crossentropy: 0.6931 - acc: 0.5100 - val_loss: 0.6943 - val_binary_crossentropy: 0.6943 - val_acc: 0.4988
# Epoch 9/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6930 - binary_crossentropy: 0.6930 - acc: 0.5112 - val_loss: 0.6943 - val_binary_crossentropy: 0.6943 - val_acc: 0.4974
# Epoch 10/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6929 - binary_crossentropy: 0.6929 - acc: 0.5124 - val_loss: 0.6935 - val_binary_crossentropy: 0.6935 - val_acc: 0.5032
# Epoch 11/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6928 - binary_crossentropy: 0.6928 - acc: 0.5129 - val_loss: 0.6950 - val_binary_crossentropy: 0.6950 - val_acc: 0.4954
# Epoch 12/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6929 - binary_crossentropy: 0.6929 - acc: 0.5110 - val_loss: 0.6937 - val_binary_crossentropy: 0.6937 - val_acc: 0.5039
# Epoch 13/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6927 - binary_crossentropy: 0.6927 - acc: 0.5120 - val_loss: 0.6942 - val_binary_crossentropy: 0.6942 - val_acc: 0.5017
# Epoch 14/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6928 - binary_crossentropy: 0.6928 - acc: 0.5124 - val_loss: 0.6937 - val_binary_crossentropy: 0.6937 - val_acc: 0.5028
# Epoch 15/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6926 - binary_crossentropy: 0.6926 - acc: 0.5123 - val_loss: 0.6948 - val_binary_crossentropy: 0.6948 - val_acc: 0.4943
# Epoch 16/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6928 - binary_crossentropy: 0.6928 - acc: 0.5127 - val_loss: 0.6944 - val_binary_crossentropy: 0.6944 - val_acc: 0.5005
# Epoch 17/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6927 - binary_crossentropy: 0.6927 - acc: 0.5137 - val_loss: 0.6941 - val_binary_crossentropy: 0.6941 - val_acc: 0.5009
# Epoch 18/5000
# 80000/80000 [==============================] - 2s 21us/step - loss: 0.6926 - binary_crossentropy: 0.6926 - acc: 0.5133 - val_loss: 0.6941 - val_binary_crossentropy: 0.6941 - val_acc: 0.4945
# Epoch 19/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6926 - binary_crossentropy: 0.6926 - acc: 0.5130 - val_loss: 0.6940 - val_binary_crossentropy: 0.6940 - val_acc: 0.5034
# Epoch 20/5000
# 80000/80000 [==============================] - 1s 19us/step - loss: 0.6926 - binary_crossentropy: 0.6926 - acc: 0.5139 - val_loss: 0.6955 - val_binary_crossentropy: 0.6955 - val_acc: 0.4935
# Epoch 21/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6926 - binary_crossentropy: 0.6926 - acc: 0.5132 - val_loss: 0.6943 - val_binary_crossentropy: 0.6943 - val_acc: 0.4985
# Epoch 22/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6925 - binary_crossentropy: 0.6925 - acc: 0.5142 - val_loss: 0.6946 - val_binary_crossentropy: 0.6946 - val_acc: 0.5018
# Epoch 23/5000
# 80000/80000 [==============================] - 1s 19us/step - loss: 0.6925 - binary_crossentropy: 0.6925 - acc: 0.5156 - val_loss: 0.6937 - val_binary_crossentropy: 0.6937 - val_acc: 0.5030
# Epoch 24/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6925 - binary_crossentropy: 0.6925 - acc: 0.5159 - val_loss: 0.6939 - val_binary_crossentropy: 0.6939 - val_acc: 0.5017
# Epoch 25/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6926 - binary_crossentropy: 0.6926 - acc: 0.5142 - val_loss: 0.6942 - val_binary_crossentropy: 0.6942 - val_acc: 0.5029
# Epoch 26/5000
# 80000/80000 [==============================] - 2s 21us/step - loss: 0.6925 - binary_crossentropy: 0.6925 - acc: 0.5163 - val_loss: 0.6945 - val_binary_crossentropy: 0.6945 - val_acc: 0.4988
# Epoch 27/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6924 - binary_crossentropy: 0.6924 - acc: 0.5141 - val_loss: 0.6943 - val_binary_crossentropy: 0.6943 - val_acc: 0.4979
# Epoch 28/5000
# 80000/80000 [==============================] - 1s 19us/step - loss: 0.6923 - binary_crossentropy: 0.6923 - acc: 0.5183 - val_loss: 0.6948 - val_binary_crossentropy: 0.6948 - val_acc: 0.4978
# Epoch 29/5000
# 80000/80000 [==============================] - 2s 22us/step - loss: 0.6924 - binary_crossentropy: 0.6924 - acc: 0.5158 - val_loss: 0.6942 - val_binary_crossentropy: 0.6942 - val_acc: 0.4987
# Epoch 30/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6924 - binary_crossentropy: 0.6924 - acc: 0.5168 - val_loss: 0.6945 - val_binary_crossentropy: 0.6945 - val_acc: 0.5013
# Epoch 31/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6924 - binary_crossentropy: 0.6924 - acc: 0.5152 - val_loss: 0.6946 - val_binary_crossentropy: 0.6946 - val_acc: 0.4980
# Epoch 32/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6924 - binary_crossentropy: 0.6924 - acc: 0.5144 - val_loss: 0.6943 - val_binary_crossentropy: 0.6943 - val_acc: 0.4977
# Epoch 33/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6924 - binary_crossentropy: 0.6924 - acc: 0.5163 - val_loss: 0.6942 - val_binary_crossentropy: 0.6942 - val_acc: 0.5040
# Epoch 34/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6923 - binary_crossentropy: 0.6923 - acc: 0.5172 - val_loss: 0.6948 - val_binary_crossentropy: 0.6948 - val_acc: 0.4984
# Epoch 35/5000
# 80000/80000 [==============================] - 1s 19us/step - loss: 0.6922 - binary_crossentropy: 0.6922 - acc: 0.5178 - val_loss: 0.6952 - val_binary_crossentropy: 0.6952 - val_acc: 0.4970
# Epoch 36/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6923 - binary_crossentropy: 0.6923 - acc: 0.5174 - val_loss: 0.6944 - val_binary_crossentropy: 0.6944 - val_acc: 0.5023
# Epoch 37/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6923 - binary_crossentropy: 0.6923 - acc: 0.5178 - val_loss: 0.6945 - val_binary_crossentropy: 0.6945 - val_acc: 0.5015
# Epoch 38/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6921 - binary_crossentropy: 0.6921 - acc: 0.5204 - val_loss: 0.6949 - val_binary_crossentropy: 0.6949 - val_acc: 0.5040
# Epoch 39/5000
# 80000/80000 [==============================] - 1s 19us/step - loss: 0.6922 - binary_crossentropy: 0.6922 - acc: 0.5187 - val_loss: 0.6948 - val_binary_crossentropy: 0.6948 - val_acc: 0.5056
# Epoch 40/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6922 - binary_crossentropy: 0.6922 - acc: 0.5175 - val_loss: 0.6947 - val_binary_crossentropy: 0.6947 - val_acc: 0.4959
# Epoch 41/5000
# 80000/80000 [==============================] - 1s 16us/step - loss: 0.6922 - binary_crossentropy: 0.6922 - acc: 0.5167 - val_loss: 0.6946 - val_binary_crossentropy: 0.6946 - val_acc: 0.5014
# Epoch 42/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6920 - binary_crossentropy: 0.6920 - acc: 0.5188 - val_loss: 0.6944 - val_binary_crossentropy: 0.6944 - val_acc: 0.5023
# Epoch 43/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6920 - binary_crossentropy: 0.6920 - acc: 0.5198 - val_loss: 0.6951 - val_binary_crossentropy: 0.6951 - val_acc: 0.4937
# Epoch 44/5000
# 80000/80000 [==============================] - 1s 16us/step - loss: 0.6920 - binary_crossentropy: 0.6920 - acc: 0.5194 - val_loss: 0.6942 - val_binary_crossentropy: 0.6942 - val_acc: 0.5023
# Epoch 45/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6919 - binary_crossentropy: 0.6919 - acc: 0.5204 - val_loss: 0.6955 - val_binary_crossentropy: 0.6955 - val_acc: 0.4966
# Epoch 46/5000
# 80000/80000 [==============================] - 2s 25us/step - loss: 0.6919 - binary_crossentropy: 0.6919 - acc: 0.5193 - val_loss: 0.6956 - val_binary_crossentropy: 0.6956 - val_acc: 0.5034
# Epoch 47/5000
# 80000/80000 [==============================] - 2s 22us/step - loss: 0.6920 - binary_crossentropy: 0.6920 - acc: 0.5199 - val_loss: 0.6950 - val_binary_crossentropy: 0.6950 - val_acc: 0.4946
# Epoch 48/5000
# 80000/80000 [==============================] - 2s 21us/step - loss: 0.6918 - binary_crossentropy: 0.6918 - acc: 0.5217 - val_loss: 0.6948 - val_binary_crossentropy: 0.6948 - val_acc: 0.4948
# Epoch 49/5000
# 80000/80000 [==============================] - 1s 16us/step - loss: 0.6919 - binary_crossentropy: 0.6919 - acc: 0.5199 - val_loss: 0.6945 - val_binary_crossentropy: 0.6945 - val_acc: 0.5011
# Epoch 50/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6920 - binary_crossentropy: 0.6920 - acc: 0.5177 - val_loss: 0.6948 - val_binary_crossentropy: 0.6948 - val_acc: 0.5010
# Epoch 51/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6919 - binary_crossentropy: 0.6919 - acc: 0.5178 - val_loss: 0.6948 - val_binary_crossentropy: 0.6948 - val_acc: 0.5032
# Epoch 52/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6919 - binary_crossentropy: 0.6919 - acc: 0.5190 - val_loss: 0.6948 - val_binary_crossentropy: 0.6948 - val_acc: 0.5057
# Epoch 53/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6919 - binary_crossentropy: 0.6919 - acc: 0.5203 - val_loss: 0.6952 - val_binary_crossentropy: 0.6952 - val_acc: 0.4919
# Epoch 54/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6917 - binary_crossentropy: 0.6917 - acc: 0.5188 - val_loss: 0.6949 - val_binary_crossentropy: 0.6949 - val_acc: 0.4976
# Epoch 55/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6918 - binary_crossentropy: 0.6918 - acc: 0.5214 - val_loss: 0.6945 - val_binary_crossentropy: 0.6945 - val_acc: 0.5042
# Epoch 56/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6918 - binary_crossentropy: 0.6918 - acc: 0.5196 - val_loss: 0.6955 - val_binary_crossentropy: 0.6955 - val_acc: 0.4973
# Epoch 57/5000
# 80000/80000 [==============================] - 2s 22us/step - loss: 0.6917 - binary_crossentropy: 0.6917 - acc: 0.5212 - val_loss: 0.6949 - val_binary_crossentropy: 0.6949 - val_acc: 0.4928
# Epoch 58/5000
# 80000/80000 [==============================] - 2s 21us/step - loss: 0.6917 - binary_crossentropy: 0.6917 - acc: 0.5205 - val_loss: 0.6967 - val_binary_crossentropy: 0.6967 - val_acc: 0.4988
# Epoch 59/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6917 - binary_crossentropy: 0.6917 - acc: 0.5188 - val_loss: 0.6948 - val_binary_crossentropy: 0.6948 - val_acc: 0.5016
# Epoch 60/5000
# 80000/80000 [==============================] - 2s 21us/step - loss: 0.6917 - binary_crossentropy: 0.6917 - acc: 0.5203 - val_loss: 0.6942 - val_binary_crossentropy: 0.6942 - val_acc: 0.5007
# Epoch 61/5000
# 80000/80000 [==============================] - 2s 21us/step - loss: 0.6918 - binary_crossentropy: 0.6918 - acc: 0.5190 - val_loss: 0.6944 - val_binary_crossentropy: 0.6944 - val_acc: 0.4993
# Epoch 62/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6916 - binary_crossentropy: 0.6916 - acc: 0.5200 - val_loss: 0.6957 - val_binary_crossentropy: 0.6957 - val_acc: 0.4994
# Epoch 63/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6917 - binary_crossentropy: 0.6917 - acc: 0.5198 - val_loss: 0.6950 - val_binary_crossentropy: 0.6950 - val_acc: 0.4963
# Epoch 64/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6916 - binary_crossentropy: 0.6916 - acc: 0.5214 - val_loss: 0.6950 - val_binary_crossentropy: 0.6950 - val_acc: 0.4990
# Epoch 65/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6915 - binary_crossentropy: 0.6915 - acc: 0.5235 - val_loss: 0.6954 - val_binary_crossentropy: 0.6954 - val_acc: 0.4948
# Epoch 66/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6916 - binary_crossentropy: 0.6916 - acc: 0.5220 - val_loss: 0.6953 - val_binary_crossentropy: 0.6953 - val_acc: 0.4987
# Epoch 67/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6915 - binary_crossentropy: 0.6915 - acc: 0.5244 - val_loss: 0.6947 - val_binary_crossentropy: 0.6947 - val_acc: 0.4972
# Epoch 68/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6916 - binary_crossentropy: 0.6916 - acc: 0.5207 - val_loss: 0.6953 - val_binary_crossentropy: 0.6953 - val_acc: 0.5001
# Epoch 69/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6914 - binary_crossentropy: 0.6914 - acc: 0.5220 - val_loss: 0.6951 - val_binary_crossentropy: 0.6951 - val_acc: 0.4998
# Epoch 70/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6916 - binary_crossentropy: 0.6916 - acc: 0.5218 - val_loss: 0.6955 - val_binary_crossentropy: 0.6955 - val_acc: 0.5018
# Epoch 71/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6915 - binary_crossentropy: 0.6915 - acc: 0.5220 - val_loss: 0.6952 - val_binary_crossentropy: 0.6952 - val_acc: 0.5019
# Epoch 72/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6914 - binary_crossentropy: 0.6914 - acc: 0.5224 - val_loss: 0.6964 - val_binary_crossentropy: 0.6964 - val_acc: 0.4949
# Epoch 73/5000
# 80000/80000 [==============================] - 2s 21us/step - loss: 0.6914 - binary_crossentropy: 0.6914 - acc: 0.5213 - val_loss: 0.6948 - val_binary_crossentropy: 0.6948 - val_acc: 0.5019
# Epoch 74/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6915 - binary_crossentropy: 0.6915 - acc: 0.5207 - val_loss: 0.6952 - val_binary_crossentropy: 0.6952 - val_acc: 0.5006
# Epoch 75/5000
# 80000/80000 [==============================] - 2s 21us/step - loss: 0.6914 - binary_crossentropy: 0.6914 - acc: 0.5220 - val_loss: 0.6954 - val_binary_crossentropy: 0.6954 - val_acc: 0.4994
# Epoch 76/5000
# 80000/80000 [==============================] - 1s 16us/step - loss: 0.6914 - binary_crossentropy: 0.6914 - acc: 0.5206 - val_loss: 0.6948 - val_binary_crossentropy: 0.6948 - val_acc: 0.5006
# Epoch 77/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6912 - binary_crossentropy: 0.6912 - acc: 0.5252 - val_loss: 0.6956 - val_binary_crossentropy: 0.6956 - val_acc: 0.4977
# Epoch 78/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6912 - binary_crossentropy: 0.6912 - acc: 0.5235 - val_loss: 0.6953 - val_binary_crossentropy: 0.6953 - val_acc: 0.5022
# Epoch 79/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6913 - binary_crossentropy: 0.6913 - acc: 0.5242 - val_loss: 0.6949 - val_binary_crossentropy: 0.6949 - val_acc: 0.5019
# Epoch 80/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6914 - binary_crossentropy: 0.6914 - acc: 0.5229 - val_loss: 0.6952 - val_binary_crossentropy: 0.6952 - val_acc: 0.5000
# Epoch 81/5000
# 80000/80000 [==============================] - 2s 25us/step - loss: 0.6913 - binary_crossentropy: 0.6913 - acc: 0.5246 - val_loss: 0.6956 - val_binary_crossentropy: 0.6956 - val_acc: 0.4986
# Epoch 82/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6913 - binary_crossentropy: 0.6913 - acc: 0.5225 - val_loss: 0.6949 - val_binary_crossentropy: 0.6949 - val_acc: 0.4980
# Epoch 83/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6913 - binary_crossentropy: 0.6913 - acc: 0.5238 - val_loss: 0.6952 - val_binary_crossentropy: 0.6952 - val_acc: 0.4970
# Epoch 84/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6913 - binary_crossentropy: 0.6913 - acc: 0.5235 - val_loss: 0.6953 - val_binary_crossentropy: 0.6953 - val_acc: 0.5003
# Epoch 85/5000
# 80000/80000 [==============================] - 1s 16us/step - loss: 0.6911 - binary_crossentropy: 0.6911 - acc: 0.5236 - val_loss: 0.6968 - val_binary_crossentropy: 0.6968 - val_acc: 0.4950
# Epoch 86/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6912 - binary_crossentropy: 0.6912 - acc: 0.5236 - val_loss: 0.6959 - val_binary_crossentropy: 0.6959 - val_acc: 0.4998
# Epoch 87/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6913 - binary_crossentropy: 0.6913 - acc: 0.5223 - val_loss: 0.6952 - val_binary_crossentropy: 0.6952 - val_acc: 0.5034
# Epoch 88/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6912 - binary_crossentropy: 0.6912 - acc: 0.5237 - val_loss: 0.6959 - val_binary_crossentropy: 0.6959 - val_acc: 0.4966
# Epoch 89/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6912 - binary_crossentropy: 0.6912 - acc: 0.5254 - val_loss: 0.6950 - val_binary_crossentropy: 0.6950 - val_acc: 0.5014
# Epoch 90/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6911 - binary_crossentropy: 0.6911 - acc: 0.5257 - val_loss: 0.6963 - val_binary_crossentropy: 0.6963 - val_acc: 0.4999
# Epoch 91/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6912 - binary_crossentropy: 0.6912 - acc: 0.5242 - val_loss: 0.6956 - val_binary_crossentropy: 0.6956 - val_acc: 0.4977
# Epoch 92/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6911 - binary_crossentropy: 0.6911 - acc: 0.5226 - val_loss: 0.6952 - val_binary_crossentropy: 0.6952 - val_acc: 0.5003
# Epoch 93/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6910 - binary_crossentropy: 0.6910 - acc: 0.5258 - val_loss: 0.6950 - val_binary_crossentropy: 0.6950 - val_acc: 0.5005
# Epoch 94/5000
# 80000/80000 [==============================] - 1s 16us/step - loss: 0.6912 - binary_crossentropy: 0.6912 - acc: 0.5247 - val_loss: 0.6957 - val_binary_crossentropy: 0.6957 - val_acc: 0.4979
# Epoch 95/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6911 - binary_crossentropy: 0.6911 - acc: 0.5223 - val_loss: 0.6957 - val_binary_crossentropy: 0.6957 - val_acc: 0.4968
# Epoch 96/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6912 - binary_crossentropy: 0.6912 - acc: 0.5229 - val_loss: 0.6953 - val_binary_crossentropy: 0.6953 - val_acc: 0.4981
# Epoch 97/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6911 - binary_crossentropy: 0.6911 - acc: 0.5250 - val_loss: 0.6951 - val_binary_crossentropy: 0.6951 - val_acc: 0.4982
# Epoch 98/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6910 - binary_crossentropy: 0.6910 - acc: 0.5243 - val_loss: 0.6956 - val_binary_crossentropy: 0.6956 - val_acc: 0.4985
# Epoch 99/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6910 - binary_crossentropy: 0.6910 - acc: 0.5237 - val_loss: 0.6958 - val_binary_crossentropy: 0.6958 - val_acc: 0.4978
# Epoch 100/5000
# 80000/80000 [==============================] - 2s 22us/step - loss: 0.6909 - binary_crossentropy: 0.6909 - acc: 0.5256 - val_loss: 0.6952 - val_binary_crossentropy: 0.6952 - val_acc: 0.4979
# Epoch 101/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6911 - binary_crossentropy: 0.6911 - acc: 0.5255 - val_loss: 0.6959 - val_binary_crossentropy: 0.6959 - val_acc: 0.4993
# Epoch 102/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6911 - binary_crossentropy: 0.6911 - acc: 0.5242 - val_loss: 0.6954 - val_binary_crossentropy: 0.6954 - val_acc: 0.4941
# Epoch 103/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6910 - binary_crossentropy: 0.6910 - acc: 0.5259 - val_loss: 0.6956 - val_binary_crossentropy: 0.6956 - val_acc: 0.5000
# Epoch 104/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6909 - binary_crossentropy: 0.6909 - acc: 0.5252 - val_loss: 0.6957 - val_binary_crossentropy: 0.6957 - val_acc: 0.4968
# Epoch 105/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6910 - binary_crossentropy: 0.6910 - acc: 0.5248 - val_loss: 0.6953 - val_binary_crossentropy: 0.6953 - val_acc: 0.4987
# Epoch 106/5000
# 80000/80000 [==============================] - 2s 21us/step - loss: 0.6910 - binary_crossentropy: 0.6910 - acc: 0.5252 - val_loss: 0.6954 - val_binary_crossentropy: 0.6954 - val_acc: 0.5043
# Epoch 107/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6910 - binary_crossentropy: 0.6910 - acc: 0.5251 - val_loss: 0.6960 - val_binary_crossentropy: 0.6960 - val_acc: 0.4965
# Epoch 108/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6910 - binary_crossentropy: 0.6910 - acc: 0.5235 - val_loss: 0.6956 - val_binary_crossentropy: 0.6956 - val_acc: 0.5003
# Epoch 109/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6909 - binary_crossentropy: 0.6909 - acc: 0.5269 - val_loss: 0.6956 - val_binary_crossentropy: 0.6956 - val_acc: 0.4970
# Epoch 110/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6908 - binary_crossentropy: 0.6908 - acc: 0.5249 - val_loss: 0.6957 - val_binary_crossentropy: 0.6957 - val_acc: 0.4996
# Epoch 111/5000
# 80000/80000 [==============================] - 2s 21us/step - loss: 0.6909 - binary_crossentropy: 0.6909 - acc: 0.5264 - val_loss: 0.6953 - val_binary_crossentropy: 0.6953 - val_acc: 0.4949
# Epoch 112/5000
# 80000/80000 [==============================] - 2s 19us/step - loss: 0.6909 - binary_crossentropy: 0.6909 - acc: 0.5247 - val_loss: 0.6956 - val_binary_crossentropy: 0.6956 - val_acc: 0.5059
# Epoch 113/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6908 - binary_crossentropy: 0.6908 - acc: 0.5274 - val_loss: 0.6965 - val_binary_crossentropy: 0.6965 - val_acc: 0.5015
# Epoch 114/5000
# 80000/80000 [==============================] - 2s 20us/step - loss: 0.6910 - binary_crossentropy: 0.6910 - acc: 0.5242 - val_loss: 0.6957 - val_binary_crossentropy: 0.6957 - val_acc: 0.5033
# Epoch 115/5000
# 80000/80000 [==============================] - 1s 18us/step - loss: 0.6909 - binary_crossentropy: 0.6909 - acc: 0.5253 - val_loss: 0.6964 - val_binary_crossentropy: 0.6964 - val_acc: 0.4977
# Epoch 116/5000
# 80000/80000 [==============================] - 1s 16us/step - loss: 0.6908 - binary_crossentropy: 0.6908 - acc: 0.5258 - val_loss: 0.6957 - val_binary_crossentropy: 0.6957 - val_acc: 0.5005
# Epoch 117/5000
# 80000/80000 [==============================] - 1s 16us/step - loss: 0.6909 - binary_crossentropy: 0.6909 - acc: 0.5252 - val_loss: 0.6953 - val_binary_crossentropy: 0.6953 - val_acc: 0.5019
# Epoch 118/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6909 - binary_crossentropy: 0.6909 - acc: 0.5254 - val_loss: 0.6961 - val_binary_crossentropy: 0.6961 - val_acc: 0.4978
# Epoch 119/5000
# 80000/80000 [==============================] - 1s 17us/step - loss: 0.6908 - binary_crossentropy: 0.6908 - acc: 0.5253 - val_loss: 0.6959 - val_binary_crossentropy: 0.6959 - val_acc: 0.4986
# Epoch 120/5000
# 80000/80000 [==============================] - 2s 22us/step - loss: 0.6909 - binary_crossentropy: 0.6909 - acc: 0.5246 - val_loss: 0.6953 - val_binary_crossentropy: 0.6953 - val_acc: 0.4985
# Epoch 121/5000
# 22800/80000 [=======>......................] - ETA: 0s - loss: 0.6898 - binary_crossentropy: 0.6898 - acc: 0.5279
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-2e01567c400f> in <module>()
#      39                 classifier.summary()
#      40
# ---> 41                 history = classifier.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=ep, batch_size=b_size, verbose=1)
#      42                 result = classifier.evaluate(X_test, Y_test, batch_size=b_size)
#      43
#
# ~\Anaconda3\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     963                               initial_epoch=initial_epoch,
#     964                               steps_per_epoch=steps_per_epoch,
# --> 965                               validation_steps=validation_steps)
#     966
#     967     def evaluate(self, x=None, y=None,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1667                               initial_epoch=initial_epoch,
#    1668                               steps_per_epoch=steps_per_epoch,
# -> 1669                               validation_steps=validation_steps)
#    1670
#    1671     def evaluate(self, x=None, y=None,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1204                         ins_batch[i] = ins_batch[i].toarray()
#    1205
# -> 1206                     outs = f(ins_batch)
#    1207                     if not isinstance(outs, list):
#    1208                         outs = [outs]
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
from keras.utils import plot_model
plot_model(classifier, to_file='model.pdf', show_shapes=True, show_layer_names=False)
